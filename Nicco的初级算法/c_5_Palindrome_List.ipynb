# %% [markdown]
# # 回文链表
# 请判断一个链表是否为回文链表。
#
# 示例 1:
#
# >输入: 1->2
#
# >输出: false
#
# 示例 2:
#
# >输入: 1->2->2->1
#
# >输出: true
#
# 进阶：
# 你能否用 O(n) 时间复杂度和 O(1) 空间复杂度解决此题？

# %% [markdown]
# ## python
# 思路：
# + 先找到中点，然后将后面的翻转，然后与前面的一一比对；
# + 不需要考虑奇数偶数，因为两端某一端到达最后就已经是完全匹配了；
# + 翻转其实只用了O(1)空间复杂度。时间复杂度也很小；

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None
class Solution:
    def isPalindrome(self, head):
        """
        :type head: ListNode
        :rtype: bool
        """
        if not head or not head.next:
            return True
        lf: ListNode = head
        rt: ListNode = head
        while rt and rt.next and rt.next.next:
            lf = lf.next
            rt = rt.next.next
        nhalf: ListNode = lf.next if rt.next else lf
        rnhalf: ListNode = self.reverse(nhalf,None)
        rlt: bool = True
        p = head
        while(p!=lf.next):
            if(p.val!=rnhalf.val):
                rlt = False
            p = p.next
            rnhalf = rnhalf.next
        return rlt
    def reverse(self, head, st): 
        if not head:
            return st
        p = head.next
        head.next = st
        return self.reverse(p,head)

# %%
t = [1,1,2,1]
st = ListNode(0)
p = st
for i in t:
    p.next = ListNode(i)
    p = p.next
Solution().isPalindrome(st.next)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def isPalindrome(self, head):
        """
        :type head: ListNode
        :rtype: bool
        """
        if head == None or head.next == None:
            return True

        lat = head.next
        pre = head
        while lat != None and lat.next != None:
            lat = lat.next.next
            pre = pre.next

        cur = pre.next
        pre.next = None
        p = None
        while cur != None:
            q = cur.next
            cur.next = p
            p = cur
            cur = q

        while p != None and head != None:
            if p.val != head.val:
                return False
            p = p.next
            head = head.next

        return True

# %% [markdown]
# ## JAVA

# %%
class Solution {
    public boolean isPalindrome(ListNode head) {
        if(head==null||head.next==null)
            return true;
        ListNode pre=head;
        ListNode last=head;
        while(last.next!=null&&last.next.next!=null){
            pre=pre.next;
            last=last.next.next;
        }
        //翻转后半部分
        ListNode cur=pre.next;
        pre.next=null;
        ListNode s=null;
        ListNode t=cur;
        while(cur!=null){
            t=cur;
            cur=cur.next;
            t.next = s;
            s=t;
        }
        while(s!=null&&head!=null){
            if(s.val!=head.val)
                return false;
            head=head.next;
            s=s.next;
        }
        
        return true;
    }
}
